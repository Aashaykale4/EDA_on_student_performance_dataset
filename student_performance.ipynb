# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student-por.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.shape
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
sns.countplot(x='school',data=df,palette='pastel')
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_9064\3309261066.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='school',data=df,palette='pastel')
# <Axes: xlabel='school', ylabel='count'>

# %%
df.age
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 644    19
# 645    18
# 646    18
# 647    17
# 648    18
# Name: age, Length: 649, dtype: int64

# %%
sns.histplot(df.age,kde=True,color='m')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.address
# Out:
# 0      U
# 1      U
# 2      U
# 3      U
# 4      U
#       ..
# 644    R
# 645    U
# 646    U
# 647    U
# 648    R
# Name: address, Length: 649, dtype: object

# %%
df.address.value_counts()
# Out:
# address
# U    452
# R    197
# Name: count, dtype: int64

# %%
sns.countplot(x='address',data=df,palette='pastel')
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_9064\3945532337.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='address',data=df,palette='pastel')
# <Axes: xlabel='address', ylabel='count'>

# %%
reason_counts=df.reason.value_counts()

# %%
plt.pie(reason_counts,labels=reason_counts.index,autopct="%1.1f%%")
plt.legend()
plt.title('Reasons')
plt.show()

# %%
activity_count=df.activities.value_counts()
plt.pie(activity_count,labels=activity_count.index,autopct="%1.1f%%",colors=['lightpink','lightblue'])
plt.legend()
plt.title('CoCurricular Activities')
plt.show()

# %%
df.Dalc.value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %%
sns.boxplot(df.freetime)
# Out:
# <Axes: ylabel='freetime'>

# %%
df.studytime
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 644    3
# 645    2
# 646    2
# 647    1
# 648    1
# Name: studytime, Length: 649, dtype: int64

# %%
sns.histplot(df.studytime)
# Out:
# <Axes: xlabel='studytime', ylabel='Count'>

# %%
df.absences
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: absences, Length: 649, dtype: int64

# %%
df.Pstatus.value_counts()
# Out:
# Pstatus
# T    569
# A     80
# Name: count, dtype: int64

# %%
sns.boxplot(data=df,x='Pstatus',y='absences')
# Out:
# <Axes: xlabel='Pstatus', ylabel='absences'>

# %%
df.sex.value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
counts=df.Fjob.value_counts()

# %%
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='Fjob'>

# %%
df.hist(bins=100,figsize=(20,24),color='blue')
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Medu'}>,
#         <Axes: title={'center': 'Fedu'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'famrel'}>,
#         <Axes: title={'center': 'freetime'}>],
#        [<Axes: title={'center': 'goout'}>,
#         <Axes: title={'center': 'Dalc'}>,
#         <Axes: title={'center': 'Walc'}>,
#         <Axes: title={'center': 'health'}>],
#        [<Axes: title={'center': 'absences'}>,
#         <Axes: title={'center': 'G1'}>, <Axes: title={'center': 'G2'}>,
#         <Axes: title={'center': 'G3'}>]], dtype=object)

# %%
df.G1.describe()
# Out:
# count    649.000000
# mean      11.399076
# std        2.745265
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
df.G1.value_counts()
# Out:
# G1
# 10    95
# 11    91
# 12    82
# 13    72
# 14    71
# 9     65
# 8     42
# 15    35
# 7     33
# 16    22
# 17    16
# 6      9
# 18     7
# 5      5
# 4      2
# 0      1
# 19     1
# Name: count, dtype: int64

# %%
sns.countplot(df,x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.pairplot(df)
plt.show()

# %%
#do urban students score higher than rural students
sns.kdeplot(df.loc[df['address']=='U','G1'],label='Uraban',shade=True)
sns.kdeplot(df.loc[df['address']=='R','G1'],label='Rural',shade=True)
plt.title('performance comparison for G1')
plt.xlabel('Grade 1')
plt.legend()
plt.show()
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_9064\2795599385.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']=='U','G1'],label='Uraban',shade=True)
# C:\Users\A\AppData\Local\Temp\ipykernel_9064\2795599385.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']=='R','G1'],label='Rural',shade=True)
